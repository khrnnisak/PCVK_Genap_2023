# %% [markdown]
# <a href="https://colab.research.google.com/github/khrnnisak/PCVK_Genap_2023/blob/master/Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import numpy as np
import PIL
import io
import html
import time
# %matplotlib inline
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode

# %%
jokowi_img1 = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/jokowi.jpg')
jokowi_img2 = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/jokowi.jpg')

kartini_img1 = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/kartini.jpg')
kartini_img2 = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/kartini.jpg')

kucing_img1 = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/kucing.jpg')
kucing_img2 = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/kucing.jpg')

mask_img1 = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/many_cereals.jpg')
mask_img2 = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/many_cereals.jpg')

jordan_img1 = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/mjordan.jpg')
jordan_img2 = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/mjordan.jpg')

solvayconf_img1 = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/solvayconf.jpg')
solvayconf_img2 = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/solvayconf.jpg')

# %%
def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

def convertToGRAY(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

faces_rects = faceCascade.detectMultiScale(jokowi_img2, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv2.rectangle(jokowi_img2, (x,y),(x+w,y+h),(0,255,0),5)

faces_rects = faceCascade.detectMultiScale(kartini_img2, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv2.rectangle(kartini_img2, (x,y),(x+w,y+h),(0,255,0),5)

faces_rects = faceCascade.detectMultiScale(kucing_img2, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv2.rectangle(kucing_img2, (x,y),(x+w,y+h),(0,255,0), 5)

faces_rects = faceCascade.detectMultiScale(mask_img2, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv2.rectangle(mask_img2, (x,y),(x+w,y+h),(0,255,0), 5)

faces_rects = faceCascade.detectMultiScale(jordan_img2, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv2.rectangle(jordan_img2, (x,y),(x+w,y+h),(0,255,0), 3)

faces_rects = faceCascade.detectMultiScale(solvayconf_img2, scaleFactor = 1.2, minNeighbors = 5);
for (x,y,w,h) in faces_rects:
     cv2.rectangle(solvayconf_img2, (x,y),(x+w,y+h),(0,255,0), 3)

# %%
f, axarr = plt.subplots(6, 2, figsize = (15, 10))
plt.subplot(321), plt.imshow(convertToRGB(jokowi_img1))
plt.subplot(322), plt.imshow(convertToRGB(jokowi_img2))

plt.subplot(323), plt.imshow(convertToRGB(kartini_img1))
plt.subplot(324), plt.imshow(convertToRGB(kartini_img2))

plt.subplot(325), plt.imshow(convertToRGB(kucing_img1), cmap='gray')
plt.subplot(326), plt.imshow(convertToRGB(kucing_img2), cmap = 'gray')

f, axarr = plt.subplots(6, 2, figsize = (15, 10))
plt.subplot(321), plt.imshow(convertToRGB(mask_img1), cmap='gray')
plt.subplot(322), plt.imshow(convertToRGB(mask_img2), cmap='gray')

plt.subplot(323), plt.imshow(convertToRGB(jordan_img1), cmap='gray')
plt.subplot(324), plt.imshow(convertToRGB(jordan_img2), cmap='gray')

plt.subplot(325), plt.imshow(convertToRGB(solvayconf_img1), cmap='gray')
plt.subplot(326), plt.imshow(convertToRGB(solvayconf_img2), cmap='gray')
# Out:
# <ipython-input-6-d75fdaa428b7>:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(321), plt.imshow(convertToRGB(jokowi_img1))
# <ipython-input-6-d75fdaa428b7>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(322), plt.imshow(convertToRGB(jokowi_img2))
# <ipython-input-6-d75fdaa428b7>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(323), plt.imshow(convertToRGB(kartini_img1))
# ...

# %%
cascade_wajah = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalcatface.xml")

kucing_img2 = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/kucing.jpg', 0)

roi_wajah = cascade_wajah.detectMultiScale(kucing_img2)
for (x,y,w,h) in roi_wajah: 
  cv2.rectangle(kucing_img2,  (x, y), (x+w, y+h), (0, 255, 0), 3) 

plt.figure(figsize = (10, 10))

f, axarr = plt.subplots(1, 2, figsize=(15,5))
plt.subplot(121), plt.imshow(convertToRGB(kucing_img1))
plt.subplot(122), plt.imshow(convertToRGB(kucing_img2))
plt.show()

# %%
cascade_wajah = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_eye.xml")

jokowi = cv2.imread('/content/drive/MyDrive/PCVK/facedet/facedet/jokowi.jpg')
jokowi_gray = convertToGRAY(jokowi)

roi_wajah = cascade_wajah.detectMultiScale(jokowi_gray)
for (x,y,w,h) in roi_wajah: 
  cv2.rectangle(jokowi_gray, (x, y), (x+w, y+h), (255, 255, 255), 3)

f, axarr = plt.subplots(1, 2, figsize=(15, 15))
plt.subplot(121), plt.imshow(convertToGRAY(jokowi_img1), cmap='gray')
plt.subplot(122), plt.imshow(jokowi_gray, cmap='gray')
plt.show()

# %%
def js_to_image(js_reply):
  image_bytes = b64decode(js_reply.split(',')[1])
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

def bbox_to_bytes(bbox_array):
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  bbox_PIL.save(iobuf, format='png')
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64decode(iobuf.getvalue()), 'utf-8')))
  
  return bbox_to_bytes

# %%
face_cascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))

# %%
def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality){
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)

  data = eval_js('takePhoto({})'.format(quality))
  img = js_to_image(data)
  gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
  print(gray.shape)
  faces = face_cascade.detectMultiScale(gray)
  for(x,y,w,h) in faces:
    img = cv2.rectangle(img,(x,y),(x+w,y+h),(255, 0, 0),2)

  cv2.imwrite(filename, img)

  return filename

# %%
image = cv2.cvtColor(jordan_img1, cv2.COLOR_BGR2GRAY)
figure_size = 9

new_image = cv2.medianBlur(image, figure_size)
f, axarr = plt. subplots(1,2,figsize=(15,15))
plt.subplot(121), plt.imshow(image, cmap='gray'),plt.title('Original')
plt.subplot(122), plt.imshow(new_image, cmap='gray'),plt.title('Median Filter')
plt.show()
